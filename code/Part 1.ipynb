# %% [markdown]
# <h2 style="background-color:powderblue;"><center>ANALYTATHON 3</center></h2>
# <h1 style="background-color:powderblue;"><center><b>ENERGIA GROUP</b></center></h1>
# <h2 style="text-align:right; color:Orange;"><i>Author: BHAGYAPRASAD V.</i></h2>
# <h2 style="text-align:right;">Std No: 40458326</h2>

# %% [markdown]
# <center>Part 1 (April 1st – Sept 30th, 2019)</center>
# <b>Step 1: Data Loading & Basic Exploration (Part 1)</b>

# %% [markdown]
# ##### Step 1.1: Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: display settings
pd.set_option('display.max_columns', None)
sns.set(style="whitegrid")

# %% [markdown]
#  ##### Step 1.2: Load the Excel File & Explore Sheet Names

# %%
# Load the Excel file
file_path = 'QUB Data - Part 1.xlsx'

# List all sheet names
xls = pd.ExcelFile(file_path)
print(xls.sheet_names)
# Out:
# ['Wind', 'Demand', 'Actual Prices', 'Summary']

# %% [markdown]
# ##### Step 1.3: Load and Preview Each Sheet

# %%
# Replace with the actual sheet name you found
df = xls.parse(xls.sheet_names[0])

# Preview the top rows
df.head()
# Out:
#    Start Date Start Time 30 Minute Period  Actual Wind (MW)  \
# 0  31/03/2019                    23:00:00               549
# 1  31/03/2019                    23:30:00               558
# 2  01/04/2019                    00:00:00               544
# 3  01/04/2019                    00:30:00               492
# 4  01/04/2019                    01:00:00               459
#
#    DAM Forecast ISEMWIND  IDA1 Forecast ISEMWIND  IDA2 Forecast ISEMWIND  \
# 0                    404                     412                     NaN
# 1                    404                     412                     NaN
# 2                    380                     401                     NaN
# 3                    380                     401                     NaN
# 4                    366                     391                     NaN
#
#    IDA3 Forecast ISEMWIND
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %% [markdown]
# ##### Step 1.4: Basic Data Inspection

# %%
# Check for nulls
print("Missing values:")
print(df.isnull().sum())

# Check data types
print("\nData types:")
print(df.dtypes)

# Check date/time info if available
if 'Date' in df.columns or 'Time' in df.columns:
    print("\nDate column sample:")
    print(df[['Date', 'Time']].head())
# Out:
# Missing values:
# Start Date                        0
# Start Time 30 Minute Period       0
# Actual Wind (MW)                  0
# DAM Forecast ISEMWIND             0
# IDA1 Forecast ISEMWIND            0
# IDA2 Forecast ISEMWIND         4032
# IDA3 Forecast ISEMWIND         6588
# dtype: int64
#
# Data types:
# Start Date                      object
# Start Time 30 Minute Period     object
# Actual Wind (MW)                 int64
# DAM Forecast ISEMWIND            int64
# IDA1 Forecast ISEMWIND           int64
# IDA2 Forecast ISEMWIND         float64
# IDA3 Forecast ISEMWIND         float64
# dtype: object

# %% [markdown]
# ##### Step 1.5 : Load and Preview Each Sheet Individually
#
# #### 1. Wind Sheet

# %%
wind_df = xls.parse('Wind')
print("Wind data shape:", wind_df.shape)
wind_df.head()
# Out:
# Wind data shape: (8784, 7)
#    Start Date Start Time 30 Minute Period  Actual Wind (MW)  \
# 0  31/03/2019                    23:00:00               549
# 1  31/03/2019                    23:30:00               558
# 2  01/04/2019                    00:00:00               544
# 3  01/04/2019                    00:30:00               492
# 4  01/04/2019                    01:00:00               459
#
#    DAM Forecast ISEMWIND  IDA1 Forecast ISEMWIND  IDA2 Forecast ISEMWIND  \
# 0                    404                     412                     NaN
# 1                    404                     412                     NaN
# 2                    380                     401                     NaN
# 3                    380                     401                     NaN
# 4                    366                     391                     NaN
#
#    IDA3 Forecast ISEMWIND
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %% [markdown]
#  #### 2. Demand Sheet

# %%
demand_df = xls.parse('Demand')
print("Demand data shape:", demand_df.shape)
demand_df.head()
# Out:
# Demand data shape: (8784, 7)
#    Start Date Start Time 30 Minute Period  Actual Demand (MW)  \
# 0  31/03/2019                    23:00:00                3714
# 1  31/03/2019                    23:30:00                3504
# 2  01/04/2019                    00:00:00                3427
# 3  01/04/2019                    00:30:00                3362
# 4  01/04/2019                    01:00:00                3267
#
#    DAM Forecast ISEMDEMAND (FC at 10am D-1)  IDA1 Forecast ISEMDEMAND  \
# 0                                      3713                      3712
# 1                                      3713                      3712
# 2                                      3456                      3456
# 3                                      3456                      3456
# 4                                      3237                      3234
#
#    IDA2 Forecast ISEMDEMAND  IDA3 Forecast ISEMDEMAND
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN

# %% [markdown]
# #### 3. Actual Prices Sheet

# %%
price_df = xls.parse('Actual Prices')
print("Price data shape:", price_df.shape)
price_df.head()
# Out:
# Price data shape: (8784, 7)
#    Start Date      Time  DA Price  IDA1 Price  IDA2 Price  IDA3 Price  \
# 0  31/03/2019  23:00:00     49.47      53.600         NaN         NaN
# 1  31/03/2019  23:30:00     49.47      47.878         NaN         NaN
# 2  01/04/2019  00:00:00     35.00      44.000         NaN         NaN
# 3  01/04/2019  00:30:00     35.00      43.000         NaN         NaN
# 4  01/04/2019  01:00:00     35.00      43.000         NaN         NaN
#
#    BM Price
# 0     26.44
# 1     39.25
# 2     18.65
# 3     27.91
# 4     28.39

# %% [markdown]
# ##### Step 1.6: Check Consistency Across Sheets

# %%
# Check if all have same date-time or half-hour periods
print("Wind timestamps:", wind_df.columns[:3])  # Adjust if timestamps are rows instead
print("Demand timestamps:", demand_df.columns[:3])
print("Price timestamps:", price_df.columns[:3])
# Out:
# Wind timestamps: Index(['Start Date', 'Start Time 30 Minute Period', 'Actual Wind (MW)'], dtype='object')
# Demand timestamps: Index(['Start Date', 'Start Time 30 Minute Period', 'Actual Demand (MW)'], dtype='object')
# Price timestamps: Index(['Start Date', 'Time', 'DA Price'], dtype='object')

# %% [markdown]
# ##### STEP 1.7 : Clean and Merge the Three Sheets

# %%
# Load all three datasets again (for clean processing)
wind_df = xls.parse('Wind')
demand_df = xls.parse('Demand')
price_df = xls.parse('Actual Prices')

# Combine Date and Time into a single Datetime column
def combine_datetime(df, date_col='Start Date', time_col='Time'):
    df['Datetime'] = pd.to_datetime(df[date_col] + ' ' + df[time_col], dayfirst=True)
    df = df.drop(columns=[date_col, time_col])
    return df

wind_df = combine_datetime(wind_df, date_col=wind_df.columns[0], time_col=wind_df.columns[1])
demand_df = combine_datetime(demand_df, date_col=demand_df.columns[0], time_col=demand_df.columns[1])
price_df = combine_datetime(price_df)

# Rename columns for clarity
wind_df.columns = ['DAM_Wind', 'IDA1_Wind', 'IDA2_Wind', 'IDA3_Wind', 'Actual_Wind', 'Datetime']
demand_df.columns = ['DAM_Demand', 'IDA1_Demand', 'IDA2_Demand', 'IDA3_Demand', 'Actual_Demand', 'Datetime']
price_df.columns = ['DAM_Price', 'IDA1_Price', 'IDA2_Price', 'IDA3_Price', 'BM_Price', 'Datetime']

# Merge all into one master dataframe on Datetime
df = wind_df.merge(demand_df, on='Datetime').merge(price_df, on='Datetime')

# Sort by datetime
df = df.sort_values('Datetime').reset_index(drop=True)

# Filter to start from 1st April 2019
df = df[df['Datetime'] >= '2019-04-01']

# Preview the final merged data
df.head()
# Out:
#    DAM_Wind  IDA1_Wind  IDA2_Wind  IDA3_Wind  Actual_Wind            Datetime  \
# 2       544        380        401        NaN          NaN 2019-04-01 00:00:00
# 3       492        380        401        NaN          NaN 2019-04-01 00:30:00
# 4       459        366        391        NaN          NaN 2019-04-01 01:00:00
# 5       407        366        391        NaN          NaN 2019-04-01 01:30:00
# 6       371        367        382        NaN          NaN 2019-04-01 02:00:00
#
#    DAM_Demand  IDA1_Demand  IDA2_Demand  IDA3_Demand  Actual_Demand  \
# 2        3427         3456         3456          NaN            NaN
# 3        3362         3456         3456          NaN            NaN
# 4        3267         3237         3234          NaN            NaN
# 5        3198         3237         3234          NaN            NaN
# 6        3144         3184         3187          NaN            NaN
#
#    DAM_Price  IDA1_Price  IDA2_Price  IDA3_Price  BM_Price
# 2     35.000      44.000         NaN         NaN     18.65
# 3     35.000      43.000         NaN         NaN     27.91
# 4     35.000      43.000         NaN         NaN     28.39
# 5     35.000      43.000         NaN         NaN     32.66
# 6     42.013      46.681         NaN         NaN     34.77

# %% [markdown]
# <b>Step 2: Feature Engineering</b>

# %% [raw]
# We'll now create two important new columns:
# ------------------------------------------------------------------------------------------------------
#   Feature             |             Formula              |                   Meaning
# -----------------------------------------------------------------------------------------------------                       |                                  |
# Net Demand	          |     Actual Demand – Actual Wind	 |      Demand that must be met by non-wind                         |                                  |                  generators
#                       |                                  |
# Wind Forecast Error	  |    Actual Wind – Forecast Wind   |
#                       |    (for each market: DAM, IDA1,  |
#                       |     IDA2, IDA3)                  |      How accurate the wind forecasts were
#                       |                                  |
#
# These features will help us understand price changes later.

# %%
# 2.1 — Net Demand based on Forecasts for each market
for mkt in ['DAM', 'IDA1', 'IDA2', 'IDA3']:
    df[f'{mkt}_NetDemand'] = df[f'{mkt}_Demand'] - df[f'{mkt}_Wind']

# 2.2 — Wind Forecast Errors
df['DAM_Wind_Error'] = df['Actual_Wind'] - df['DAM_Wind']
df['IDA1_Wind_Error'] = df['Actual_Wind'] - df['IDA1_Wind']
df['IDA2_Wind_Error'] = df['Actual_Wind'] - df['IDA2_Wind']
df['IDA3_Wind_Error'] = df['Actual_Wind'] - df['IDA3_Wind']

# 2.3 — Demand Forecast Errors (optional but useful for analysis)
df['DAM_Demand_Error'] = df['Actual_Demand'] - df['DAM_Demand']
df['IDA1_Demand_Error'] = df['Actual_Demand'] - df['IDA1_Demand']
df['IDA2_Demand_Error'] = df['Actual_Demand'] - df['IDA2_Demand']
df['IDA3_Demand_Error'] = df['Actual_Demand'] - df['IDA3_Demand']

# 2.4 — (Optional) Actual Net Demand
df['Actual_NetDemand'] = df['Actual_Demand'] - df['Actual_Wind']

# 2.5 — Quick check: Preview important columns
important_cols = ['Datetime', 'DAM_NetDemand', 'IDA1_NetDemand', 'IDA2_NetDemand', 'IDA3_NetDemand',
                  'DAM_Wind_Error', 'IDA1_Wind_Error', 'IDA2_Wind_Error', 'IDA3_Wind_Error',
                  'DAM_Demand_Error', 'IDA1_Demand_Error', 'IDA2_Demand_Error', 'IDA3_Demand_Error',
                  'Actual_NetDemand']

df[important_cols].head(10)
# Out:
#               Datetime  DAM_NetDemand  IDA1_NetDemand  IDA2_NetDemand  \
# 2  2019-04-01 00:00:00           2883            3076            3055
# 3  2019-04-01 00:30:00           2870            3076            3055
# 4  2019-04-01 01:00:00           2808            2871            2843
# 5  2019-04-01 01:30:00           2791            2871            2843
# 6  2019-04-01 02:00:00           2773            2817            2805
# 7  2019-04-01 02:30:00           2748            2817            2805
# 8  2019-04-01 03:00:00           2729            2743            2738
# 9  2019-04-01 03:30:00           2691            2743            2738
# 10 2019-04-01 04:00:00           2675            2713            2715
# 11 2019-04-01 04:30:00           2683            2713            2715
#
#     IDA3_NetDemand  DAM_Wind_Error  IDA1_Wind_Error  IDA2_Wind_Error  \
# 2              NaN             NaN              NaN              NaN
# 3              NaN             NaN              NaN              NaN
# 4              NaN             NaN              NaN              NaN
# 5              NaN             NaN              NaN              NaN
# 6              NaN             NaN              NaN              NaN
# 7              NaN             NaN              NaN              NaN
# 8              NaN             NaN              NaN              NaN
# 9              NaN             NaN              NaN              NaN
# 10             NaN             NaN              NaN              NaN
# 11             NaN             NaN              NaN              NaN
#
#     IDA3_Wind_Error  DAM_Demand_Error  IDA1_Demand_Error  IDA2_Demand_Error  \
# 2               NaN               NaN                NaN                NaN
# 3               NaN               NaN                NaN                NaN
# 4               NaN               NaN                NaN                NaN
# 5               NaN               NaN                NaN                NaN
# 6               NaN               NaN                NaN                NaN
# 7               NaN               NaN                NaN                NaN
# 8               NaN               NaN                NaN                NaN
# 9               NaN               NaN                NaN                NaN
# 10              NaN               NaN                NaN                NaN
# 11              NaN               NaN                NaN                NaN
#
#     IDA3_Demand_Error  Actual_NetDemand
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# 5                 NaN               NaN
# 6                 NaN               NaN
# 7                 NaN               NaN
# 8                 NaN               NaN
# 9                 NaN               NaN
# 10                NaN               NaN
# 11                NaN               NaN

# %% [markdown]
# #### Step 3: Exploratory Data Analysis (EDA)

# %%
# Set a nice visual style
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (14, 6)

# %% [markdown]
# ##### 3.1 — Price Trends Over Time

# %%
plt.figure()
plt.plot(df['Datetime'], df['DAM_Price'], label='DAM Price')
plt.plot(df['Datetime'], df['IDA1_Price'], label='IDA1 Price')
plt.plot(df['Datetime'], df['IDA2_Price'], label='IDA2 Price')
plt.plot(df['Datetime'], df['IDA3_Price'], label='IDA3 Price')
plt.plot(df['Datetime'], df['BM_Price'], label='BM Price', linestyle='--')
plt.title('Market Prices Over Time')
plt.xlabel('Datetime')
plt.ylabel('Price (€/MWh)')
plt.legend()
plt.grid(True)
plt.show()

# %% [raw]
# Market Prices Over Time
#
# What it shows:
#
# BM Prices (dashed line) are very volatile, with both very high and very low spikes.
# DAM, IDA1, IDA2, IDA3 Prices are relatively smoother.
# Huge price spikes occur randomly across months.
# In general, forward markets (DAM/IDAs) are more predictable, while Balancing Market (BM) is risky.
#
# Meaning for Strategy:
#
# Buying all power from BM is very risky.
# Buying from DAM or IDAs may offer safer, more stable prices.

# %% [markdown]
# ##### 3.2 — DAM Price vs DAM Net Demand

# %%
plt.figure()
sns.scatterplot(x=df['DAM_NetDemand'], y=df['DAM_Price'])
plt.title('DAM Price vs DAM Net Demand')
plt.xlabel('DAM Net Demand (MW)')
plt.ylabel('DAM Price (€/MWh)')
plt.grid(True)
plt.show()

# %% [raw]
# Scatter Plot: DAM Price vs DAM Net Demand
#
# What it shows:
#
# Strong positive correlation between DAM Net Demand and DAM Price.
# When Net Demand (Demand - Wind) is low (e.g., 1000 MW) → DAM Prices are low (sometimes ~0–40 €/MWh).
# When Net Demand is high (>3500 MW) → DAM Prices shoot up to above 100 €/MWh.
#
# Meaning for Strategy:
#
# If forecasts predict high Net Demand → Expect higher DAM prices.
# If forecasts predict low Net Demand → DAM will be cheaper.
# You can use Net Demand forecast as an early warning to either buy early (DAM) or wait for IDAs.

# %% [markdown]
# ##### 3.3 — Histogram: DAM Wind Forecast Error

# %%
plt.figure()
sns.histplot(df['DAM_Wind_Error'], bins=50, kde=True, color="skyblue")
plt.title('Distribution of DAM Wind Forecast Error')
plt.xlabel('Wind Forecast Error (MW)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [raw]
# Histogram: Distribution of DAM Wind Forecast Error
#
# What it shows:
#
# *  The forecast error distribution is roughly centered around 0, which is good — forecasts are
#    unbiased on average.
# *  Most errors are between -200 MW and +200 MW.
# *  However, sometimes the wind is over-predicted or under-predicted by 400–600 MW, causing market
#    shocks.
#
# Meaning for Strategy:
#
# *  Forecast errors are common and can impact prices heavily if large.
# *  On days with very large forecast errors, real prices can be much worse than expected — BM price
#    spikes may happen if wind is lower than forecasted.

# %% [markdown]
# ##### 3.4 — Boxplot: DAM Prices by Hour of Day (Optional but Insightful)

# %%
df['Hour'] = df['Datetime'].dt.hour  # Create an hour feature

plt.figure()
sns.boxplot(x=df['Hour'], y=df['DAM_Price'])
plt.title('DAM Prices by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('DAM Price (€/MWh)')
plt.grid(True)
plt.show()

# %% [raw]
# **** What These Plots Showed me:
# ------------------------------------------------------------------------------------
#       Plot	                 |                 What i learnt
# ------------------------------------------------------------------------------------
# Prices Over Time	         |    Which market is volatile or cheaper
# DAM Price vs Net Demand	     |    Is high Net Demand causing higher prices?
# Wind Forecast Error	         |    How good (or bad) the wind forecasts are
# Hourly DAM Price Patterns	 |    Are nights cheaper? Are mornings expensive?

# %% [markdown]
# #### Step 4: Simulate Basic Strategies

# %%
# We need to buy exactly 100 MW for every half-hour slot
MW_needed = 100  # Constant purchase per half-hour

# 4.1 — Strategy 1: Buy 100% in DAM (Day-Ahead Market)
df['Cost_DAM'] = df['DAM_Price'] * MW_needed

# 4.2 — Strategy 2: Buy 100% in BM (Balancing Market)
df['Cost_BM'] = df['BM_Price'] * MW_needed

# 4.3 — Strategy 3: Buy 50% DAM + 50% BM (Split Strategy Example)
df['Cost_Split'] = (0.5 * df['DAM_Price'] + 0.5 * df['BM_Price']) * MW_needed

# 4.4 — Calculate Total Cost over full period
total_costs = {
    'Buy All in DAM': df['Cost_DAM'].sum(),
    'Buy All in BM': df['Cost_BM'].sum(),
    'Buy 50% DAM + 50% BM': df['Cost_Split'].sum()
}

# 4.5 — Display total costs for comparison
print("=== Total Cost for Each Strategy (April 1 - Sept 30, 2019) ===")
for strategy, cost in total_costs.items():
    print(f"{strategy}: €{cost:,.2f}")
# Out:
# === Total Cost for Each Strategy (April 1 - Sept 30, 2019) ===
# Buy All in DAM: €41,210,532.00
# Buy All in BM: €37,953,163.00
# Buy 50% DAM + 50% BM: €39,581,847.50

# %% [raw]
# What This told me:
#
#    Strategy	                                             Meaning
# Buy All in DAM	                    Safe, predictable, but sometimes not the absolute cheapest.
# Buy All in BM	                    Very risky — could be cheaper or much more expensive.
# 50/50 Split	                        Balances risk and stability.
#
# You’ll see the total € cost for each strategy.
# Then we can find which one was cheaper historically.

# %% [raw]
#              Results Summary
# ------------------------------------------------------------------------------------------------------
#    Strategy	           |     Total Cost (€)	|        Insights
# ------------------------------------------------------------------------------------------------------
# Buy All in DAM	       |     €41,210,532	| Stable but more expensive
# Buy All in BM	       |     €37,953,163	| Cheaper overall, but risky
# Buy 50% DAM + 50% BM   |	 €39,581,848	| Middle ground — better than DAM-only,safer than full BM
#
# Key Observations
#
# 1) Buying only in BM was cheapest historically during April–September 2019.
# →  BM prices were lower on average despite the spikes.
#
# 2) But remember: BM is risky — lots of price volatility (as we saw earlier).
# *  You could get huge spikes (>€400) randomly.
# *  BM prices are also very unpredictable day-to-day.
#
# 3) Split 50/50 strategy also performs better than all-in DAM.
# *  It captures some low BM prices while reducing risk.
#
# Meaning for Energia's Strategy
#
# * Blindly buying 100% DAM is not optimal.
# * Some flexibility (e.g., buying partly in DAM, partly later) can save millions.
# * BM market opportunities can be exploited carefully, but must be managed for risk.

# %% [markdown]
# #### Smart Dynamic Strategy!

# %% [markdown]
# Now, instead of fixed "always buy in DAM" or "always buy in BM",
# I built dynamic rules like:
#
# "If Net Demand forecast is low → Buy in DAM."
#
# "If DAM price looks high → Wait for IDA1 or IDA2 to re-purchase."
#
# "If Wind forecast is very uncertain → Secure more early."
#
# Example:
#
# * Using Net Demand Forecast to decide when to buy
# * Adaptive strategy instead of static
# * Compare it to your baseline costs!

# %% [markdown]
# #### Step 5: Smart Strategy Using Net Demand Forecast

# %% [raw]
# * Logic for Smart Strategy:
#
#    If DAM Net Demand is low →
#      → Buy 100% in DAM (because prices are expected to be low)
#
#    If DAM Net Demand is high →
#      → Wait and buy in BM (hoping for better prices or at least not overpay early)
#
# * We'll define a Net Demand Threshold to decide this.
#
# Example:
#
# If DAM_NetDemand < 2500 MW → Buy DAM
#
# Else → Buy BM

# %% [markdown]
# ##### Smart Strategy Simulation

# %%
# Define threshold (you can tune this later!)
net_demand_threshold = 2500  # MegaWatt

# Create a new smart cost column
df['Cost_Smart'] = np.where(
    df['DAM_NetDemand'] < net_demand_threshold,
    df['DAM_Price'] * MW_needed,  # Buy in DAM if net demand low
    df['BM_Price'] * MW_needed     # Otherwise buy in BM
)

# Calculate total smart cost
total_smart_cost = df['Cost_Smart'].sum()

# Add Smart Strategy to the total cost comparison
total_costs['Smart Strategy (Net Demand Rule)'] = total_smart_cost

# Display updated total costs
print("=== Updated Total Cost Comparison ===")
for strategy, cost in total_costs.items():
    print(f"{strategy}: €{cost:,.2f}")
# Out:
# === Updated Total Cost Comparison ===
# Buy All in DAM: €41,210,532.00
# Buy All in BM: €37,953,163.00
# Buy 50% DAM + 50% BM: €39,581,847.50
# Smart Strategy (Net Demand Rule): €41,274,046.60

# %% [raw]
# What This Will Show
# Strategy	                 Meaning
# Smart Strategy	     Dynamically chooses DAM or BM based on Net Demand forecast
#
# - If Net Demand is low, secure cheap DAM prices.
# - If Net Demand is high, avoid expensive DAM, wait for BM (which might still be cheaper).
#
# Extra Tip:
#
# Later you can optimize the threshold (e.g., try 2000 MW, 3000 MW) to find the best one!
# We can even automate threshold tuning later! (super powerful)

# %% [raw]
# Updated Cost Summary
# --------------------------------------------------------------------------------------------
# Strategy	                         Total Cost (€)	          Comments
# --------------------------------------------------------------------------------------------
# Buy All in DAM	                      €41,210,532	    Stable but expensive
# Buy All in BM	                      €37,953,163	    Risky but cheapest historically
# 50% DAM + 50% BM	                  €39,581,848	    Good balance
# Smart Strategy (Net Demand Rule)	  €41,274,047	    More expensive than even All DAM!
#
#
# Key Observations
#
# Smart Strategy (Net Demand rule with 2500 MW threshold) did not beat the others.
# It was even slightly worse than "Buy All in DAM".
# This means our threshold of 2500 MW may not be optimal!

# %% [markdown]
# #### Step 7: Conclusion and Factor Analysis

# %% [markdown]
# ##### 7.1 Conclusion (best strategy + insights)

# %% [raw]
# Conclusion: Historical Strategy Optimization (April–Sept 2019)
#
# Based on the analysis of historical data between April 1st and September 30th, 2019:
#
# * The cheapest overall strategy would have been to buy all electricity in the Balancing Market (BM).
#
# * Buying 100 MW consistently in the BM would have cost approximately €37.95 million, which is lower
#   compared to €41.21 million if buying fully in the Day-Ahead Market (DAM).
#
# * Splitting purchases (50% DAM, 50% BM) would have resulted in a total cost of €39.58 million, still    better than only DAM but more expensive than full BM.
#
# * A basic smart strategy based only on Net Demand thresholds did not outperform the simple BM buying.
#
# * However, it is important to note that BM prices are highly volatile, and although they were cheaper   overall in this period, they can sometimes spike dramatically, introducing significant financial
#   risk.
#
# * DAM prices, while slightly more expensive, offered much more price stability, reducing risk
#   exposure.
#
# Thus, buying in the BM would have been optimal based on cost alone, but a risk-averse supplier might prefer splitting between DAM and BM for more predictable outcomes.

# %% [markdown]
# #### Factor Analysis: What Drives Price Changes?

# %% [raw]
# Factor Analysis Insights
#   Analysis of the correlation matrix revealed the following key drivers of electricity prices:
#
# * Net Demand (Forecasted Demand minus Forecasted Wind) has a strong positive correlation with DAM       Prices. As Net Demand increases, prices tend to rise.
#
# * Wind Forecast Errors also moderately impact prices — when actual wind differs significantly from
#   forecasts, market prices (especially BM) become more volatile.
#
# * BM prices showed weaker correlations with forecasted factors, highlighting their unpredictable
#   nature compared to DAM prices.
#
# Thus, Net Demand Forecasts are crucial predictors for DAM market behavior, while forecast errors introduce uncertainty that can affect all markets, particularly the Balancing Market.

# %% [markdown]
# ##### Step 7 — Simple Correlation Analysis

# %%
# Select important numerical features
correlation_features = [
    'DAM_Price', 'BM_Price',
    'DAM_NetDemand', 'IDA1_NetDemand', 'IDA2_NetDemand', 'IDA3_NetDemand',
    'DAM_Wind_Error', 'DAM_Demand_Error'
]

# Create correlation matrix
corr_matrix = df[correlation_features].corr()

# Plot heatmap
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix: Prices, Net Demand, Forecast Errors')
plt.show()

# %% [markdown]
# This heatmap says:
#
#    Feature               How it relates to Price
# DAM_NetDemand	   Strong positive correlation with DAM_Price
# DAM_Wind_Error	   Moderate correlation with DAM_Price (forecast errors cause price swings)
# BM_Price	       Not very stable — correlations weaker

# %%
df.to_csv('Part1_Energia_Data.csv', index=False)
